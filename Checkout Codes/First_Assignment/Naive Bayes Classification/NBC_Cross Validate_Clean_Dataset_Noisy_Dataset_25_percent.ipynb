# %%
#Handle all major imports
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import VarianceThreshold
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading all the datasets required
#Load the original PIMA Dataset
dataset = pd.read_csv('data/pima_diabetes_clean.csv')
#Load the 25p corrupted PIMA Dataset
dataset_20 = pd.read_csv('data/pima_diabetes_25_per.csv')

# %%
#Describe the  original dataset
print(dataset.describe())
X = dataset.iloc[:, 0:8]
y = dataset.iloc[:, 8]
#Describe the 25p corrupted dataset
print(dataset_20.describe())
X_20 = dataset_20.iloc[:, 0:8]
y_20 = dataset_20.iloc[:, 8]
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean     88.614583   95.396482      79.922321      31.423324   65.725757
# std     187.391982   57.151039      30.027364      26.147995  103.700536
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       2.000000   74.000000      66.000000      11.000000    0.000000
# 50%       5.000000  107.000000      76.000000      28.500000   24.617375
# 75%      11.000000  134.000000      89.726561      44.383869   94.000000
# max     765.000000  198.000000     203.835599     100.204051  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    43.817593                  7.579313   26.224579    0.348958
# std     60.470423                 13.667400   16.876629    0.476951
# min      0.000000                  0.078000    0.006258    0.000000
# 25%     25.575000                  0.261000   21.000000    0.000000
# 50%     32.000000                  0.501500   26.000000    0.000000
# 75%     38.625000                  1.224000   37.000000    1.000000
# max    846.632787                 56.841249   81.000000    1.000000

# %%
#View The Correlation matrix for original dataset
sns.heatmap(X.corr(), annot = True)

# %%
#View The Correlation matrix for 25p corrupted dataset
sns.heatmap(X_20.corr(), annot = True)

# %%
#Feature Extraction for original
## Var[X] = p(1-p)
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
X_filtered = sel.fit_transform(X)

print(X.head(1))
print(X_filtered[0])
#DiabetesPedigreeFunction was dropped
X = X.drop('DiabetesPedigreeFunction', axis=1)

top_4_features = SelectKBest(score_func=chi2, k=4)
X_top_4_features = top_4_features.fit_transform(X, y)
print(X.head())
print(X_top_4_features)
X = X.drop(['Pregnancies', 'BloodPressure', 'SkinThickness'], axis=1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# [  6.  148.   72.   35.    0.   33.6  50. ]
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age
# 0            6      148             72             35        0  33.6   50
# 1            1       85             66             29        0  26.6   31
# 2            8      183             64              0        0  23.3   32
# 3            1       89             66             23       94  28.1   21
# 4            0      137             40             35      168  43.1   33
# [[148.    0.   33.6  50. ]
#  [ 85.    0.   26.6  31. ]
#  [183.    0.   23.3  32. ]
#  ...
#  [121.  112.   26.2  30. ]
#  [126.    0.   30.1  47. ]
#  [ 93.    0.   30.4  23. ]]

# %%
#Feature Extraction for 25 percent noise data
## Var[X] = p(1-p)
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
X_20_filtered = sel.fit_transform(X_20)

print(X_20.head(1))
print(X_20_filtered[0])
#DiabetesPedigreeFunction was dropped
X_20 = X_20.drop('DiabetesPedigreeFunction', axis=1)

top_4_features = SelectKBest(score_func=chi2, k=4)
X_20_top_4_features = top_4_features.fit_transform(X_20, y_20)
print(X_20.head())
print(X_20_top_4_features)
X_20 = X_20.drop(['Pregnancies', 'BloodPressure', 'SkinThickness'], axis=1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      0.0  33.6
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# [  6.    148.     72.     35.      0.     33.6     0.627  50.   ]
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI   Age
# 0            6    148.0           72.0           35.0      0.0  33.6  50.0
# 1            1     85.0           66.0           29.0      0.0  26.6  31.0
# 2            8    183.0           64.0            0.0      0.0  23.3  32.0
# 3            1     89.0           66.0           23.0     94.0  28.1  21.0
# 4            0    137.0           40.0           35.0    168.0  43.1  33.0
# [[  6.  148.    0.   33.6]
#  [  1.   85.    0.   26.6]
#  [  8.  183.    0.   23.3]
#  ...
#  [  5.  121.  112.   26.2]
#  [  1.  126.    0.   30.1]
#  [  1.   93.    0.   30.4]]

# %%
#Splitting the Original dataset 80/20 for train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.20)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#      Glucose  Insulin   BMI  Age
# 603      150      126  35.2   54
# 118       97        0  28.2   22
# 247      165      680  52.3   23
# 157      109      135  25.2   23
# 468      120        0  30.0   38
# 193      135        0  52.3   40
# 306      161      132  25.5   47
# 319      194        0  23.5   59
# 97        71       76  20.4   22
# 530      122      106  29.8   22
# 327      179        0  35.1   37
# 619      119        0  32.4   24
# 518       76        0  32.8   41
# 632      111        0  26.2   23
# 524      125        0  31.6   24
# 536      105        0  29.6   46
# 597       89       25  27.8   21
# 462       74       49  35.3   39
# 17       107        0  29.6   31
# 739      102        0  39.5   42
# 263      142        0  32.4   63
# 241       91       88  33.1   22
# 344       95        0  36.8   57
# 302       77       42  35.8   35
# 704      110      100  28.4   27
# 240       91        0  29.2   21
# 170      102        0  30.8   36
# 691      158        0  42.3   44
# 490       83       66  36.8   24
# 45       180        0  42.0   25
# ..       ...      ...   ...  ...
# 448      104       64  33.6   22
# 431       89       85  30.4   38
# 709       93      160  38.0   23
# 115      146        0  31.2   61
# 72       126        0  43.4   42
# 537       57        0  21.7   67
# 677       93        0  35.3   25
# 753      181      510  43.3   26
# 174       75       55  29.7   33
# 87       100       71  38.5   26
# 551       84      106  31.9   25
# 486      139      480  40.7   21
# 705       80        0  39.8   28
# 314      109        0  35.9   43
# 396       96      115  24.7   39
# 600      108        0  27.1   24
# 472      119        0  38.8   22
# 70       100       90  32.9   28
# 599      109      120  23.1   26
# 754      154        0  32.4   45
# 277      104      116  27.8   23
# 723      117      105  39.1   42
# 9        125        0   0.0   54
# 359      196      249  36.5   29
# 707      127      335  34.4   22
# 763      101      180  32.9   63
# 192      159        0  30.4   36
# 629       94        0  24.7   21
# 559       85        0  30.1   35
# 684      136        0   0.0   69
#
# [614 rows x 4 columns]
#      Glucose  Insulin   BMI  Age
# 661      199        0  42.9   22
# 122      107      100  33.6   23
# 113       76        0  34.0   25
# 14       166      175  25.8   51
# 529      111        0  24.6   31
# 103       81       40  26.6   24
# 338      152      171  34.2   33
# 588      176      156  33.3   52
# 395      127      275  27.7   25
# 204      103      190  37.7   55
# 31       158      245  31.6   28
# 546      187      207  43.6   53
# 278      114        0  24.9   57
# 593       82      115  28.5   25
# 737       65        0  32.0   42
# 202      108        0  27.3   32
# 175      179      130  32.7   36
# 55        73        0  23.0   21
# 479      132        0  28.0   63
# 365       99       83  34.0   30
# 417      144        0  38.5   37
# 577      118        0  42.9   21
# 172       87        0  28.9   25
# 352       61        0  34.4   46
# 27        97      140  23.2   22
# 431    0
# 709    1
# 115    1
# 72     1
# 537    0
# 677    0
# 753    1
# 174    0
# 87     0
# 551    0
# 486    0
# 705    0
# 314    1
# 396    0
# 600    0
# 472    0
# 70     1
# 599    0
# 754    1
# 277    0
# 723    0
# 9      1
# 359    1
# 707    0
# 763    0
# 192    1
# 629    0
# 559    0
# 684    0
# Name: Outcome, Length: 614, dtype: int64
# 661    1
# 122    0
# 113    0
# 14     1
# 529    0
# 103    0
# 338    1
# 588    1
# 395    0
# 204    0
# 31     1
# 546    1
# 278    0
# 593    0
# 737    0
# 202    0
# 175    1
# 55     0
# 479    0
# 365    0
# 417    1
# 577    1
# 172    0
# 352    0
# 27     0
# 605    0
# 239    0
# 744    0
# 79     0
# 496    0
#       ..
# 413    0
# 694    0
# 698    0
# 386    1
# 456    0
# 728    0
# 71     0
# 49     0
# 210    0
# 409    1
# 503    0
# 37     1
# 687    0
# 48     1
# 261    1
# 653    0
# 331    0
# 568    0
# 196    0
# 76     0
# 64     1
# 671    0
# 52     0
# 310    0
# 416    0
# 476    1
# 482    0
# 230    1
# 527    0
# 380    0
# Name: Outcome, Length: 154, dtype: int64

# %%
#Scaling the features of original dataset
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
#Implementing Gaussian NB Classifier with clean train data
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
#Predicting the test Set results with clean test data
y_pred = classifier.predict(X_test)

# %%
#Evaluating the Model
cm = confusion_matrix(y_test, y_pred)
print (cm)
print(f1_score(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[97 10]
#  [22 25]]
# 0.6097560975609756
# 0.7922077922077922

# %%
#Calculate the ROC curve and AUC
#Saving the Confusion Matrix and splitting into 4 variables 
# save confusion matrix and slice into four pieces
from sklearn import metrics
confusion = metrics.confusion_matrix(y_test, y_pred)
print(confusion)
#[row, column]
TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
# Out:
# [[97 10]
#  [22 25]]

# %%
#Steps for adjusting the Threshold
# print the first 10 predicted responses
# 1D array (vector) of binary values (0, 1)
classifier.predict(X_test)[0:10]
# Out:
# array([1, 0, 0, 1, 0, 0, 1, 1, 0, 0], dtype=int64)

# %%
# print the first 10 predicted probabilities of class membership
classifier.predict_proba(X_test)[0:10]
# Out:
# array([[0.03082556, 0.96917444],
#        [0.87643626, 0.12356374],
#        [0.92255338, 0.07744662],
#        [0.20841247, 0.79158753],
#        [0.91774295, 0.08225705],
#        [0.96203847, 0.03796153],
#        [0.32856931, 0.67143069],
#        [0.06623496, 0.93376504],
#        [0.65675664, 0.34324336],
#        [0.50883684, 0.49116316]])

# %%
# print the first 10 predicted probabilities for class 1
classifier.predict_proba(X_test)[0:10, 1]
# Out:
# array([0.96917444, 0.12356374, 0.07744662, 0.79158753, 0.08225705,
#        0.03796153, 0.67143069, 0.93376504, 0.34324336, 0.49116316])

# %%
# store the predicted probabilities for class 1
y_pred_prob = classifier.predict_proba(X_test)[:, 1]

# %%
#Plotting ROC Curve
# we pass y_test and y_pred_prob
# we do not use y_pred_class, because it will give incorrect results without generating an error
# roc_curve returns 3 objects fpr, tpr, thresholds
# fpr: false positive rate
# tpr: true positive rate
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob)

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for diabetes classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %%
#Finding out the AUC
# IMPORTANT: first argument is true values, second argument is predicted probabilities
print(metrics.roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.8266056870153111

# %%
# calculate cross-validated AUC
from sklearn.cross_validation import cross_val_score
cross_val_score(classifier, X, y, cv=10, scoring='roc_auc').mean()
# Out:
# C:\Users\souro\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.8154586894586895

# %%
#Computing the above for data with 25 percent dataset replaced with noisy data

#Scaling the features of 25p
sc_X_20 = StandardScaler()
X_train_20 = sc_X_20.fit_transform(X_train_20)
X_test_20 = sc_X_20.transform(X_test_20)

# %%
#Implementing Gaussian NB Classifier with 25p corrupted train data
classifier3 = GaussianNB()
classifier3.fit(X_train_20, y_train_20)
# Out:
# GaussianNB(priors=None)

# %%
#Predicting the test Set results with clean test data 
y_pred_20p_corrupted = classifier3.predict(X_test)

# %%
#Evaluating the Model which has 25p corrupted train data with clean test data. The truth of y used is from the clean test data
cm = confusion_matrix(y_test, y_pred_20p_corrupted)
print (cm)
print(f1_score(y_test, y_pred_20p_corrupted))
print(accuracy_score(y_test, y_pred_20p_corrupted))
# Out:
# [[98  9]
#  [25 22]]
# 0.5641025641025641
# 0.7792207792207793

# %%
#Calculating Confusion Matrix, Accuracy Score from the Classification Matrix, Classification Error, Sensitivity, 
#Specificity, False Positive Rate, Precision, 
#After this we adust the Plot the ROC Curve
#Then we calculate the AUC
#Following this set of instructions for dataset having 10 percent of the rows populated with noisy data

# %%
#Saving the Confusion Matrix and splitting into 4 variables 
# save confusion matrix and slice into four pieces
from sklearn import metrics
confusion = metrics.confusion_matrix(y_test, y_pred_20p_corrupted)
print(confusion)
#[row, column]
TP_10 = confusion[1, 1]
TN_10 = confusion[0, 0]
FP_10 = confusion[0, 1]
FN_10 = confusion[1, 0]
# Out:
# [[98  9]
#  [25 22]]

# %%
# print the first 10 predicted responses
# 1D array (vector) of binary values (0, 1)
classifier3.predict(X_test)[0:10]
# Out:
# array([1, 0, 0, 1, 0, 0, 0, 1, 0, 0], dtype=int64)

# %%
# print the first 10 predicted probabilities of class membership
classifier3.predict_proba(X_test)[0:10]
# Out:
# array([[0.18468024, 0.81531976],
#        [0.87625022, 0.12374978],
#        [0.89930826, 0.10069174],
#        [0.31343089, 0.68656911],
#        [0.82184088, 0.17815912],
#        [0.89934877, 0.10065123],
#        [0.5957454 , 0.4042546 ],
#        [0.27394016, 0.72605984],
#        [0.63298678, 0.36701322],
#        [0.56028906, 0.43971094]])

# %%
# store the predicted probabilities for class 1
y_pred_prob_20 = classifier3.predict_proba(X_test)[:, 1]

# %%
#Plotting ROC Curve
# we pass y_test and y_pred_prob
# we do not use y_pred_class, because it will give incorrect results without generating an error
# roc_curve returns 3 objects fpr, tpr, thresholds
# fpr: false positive rate
# tpr: true positive rate
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob_20)

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for diabetes classifier trained on data with 20 percent of the rows populated with noise')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %%
#Finding out the AUC
# IMPORTANT: first argument is true values, second argument is predicted probabilities
print(metrics.roc_auc_score(y_test, y_pred_prob_20))
# Out:
# 0.7910121296480414

# %%
# calculate cross-validated AUC
from sklearn.cross_validation import cross_val_score
cross_val_score(classifier3, X, y, cv=10, scoring='roc_auc').mean()
# Out:
# 0.8154586894586895
