# %%
import shutil
import os

files = os.listdir("../catanddogs/PetImages/Cat") 

i = 0
for key in range(0, len(files)):
    #print (files[key])
    #word_label = files[key].split('.')[-2]
#     print (word_label)
    if key <= (len(files)/5):
        shutil.move("../catanddogs/PetImages/Cat/"+files[key],"../dataset/train/cat."+files[key])
    else:
        shutil.move("../catanddogs/PetImages/Cat/"+files[key],"../dataset/test/cat."+files[key])
print ("Renamed Cat Files")

files = os.listdir("../catanddogs/PetImages/Dog") 

for key in range(0, len(files)):
    #print (files[key])
    if key <= (len(files)/5):
        shutil.move("../catanddogs/PetImages/Dog/"+files[key],"../dataset/train/dog."+files[key])
    else:
        shutil.move("../catanddogs/PetImages/Dog/"+files[key],"../dataset/test/dog."+files[key])
print ("Renamed Dog Files")
# Out:
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# Renamed Cat Files
# ...
