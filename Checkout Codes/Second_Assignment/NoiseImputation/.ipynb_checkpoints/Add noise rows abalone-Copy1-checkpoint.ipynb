# %%
import random
import pandas as pd
import numpy as np
import shutil
import os


def RandNoise(end, start, num): 
    res = []
    #print(start)
    #print(end)
    try: 
        int(start)
        for j in range(num): 
            res.append(round(random.uniform(start, end),2)) 
            #res.append(random.randint(start, end))
  
        return res 
    except ValueError:
        list = ['M','F','I']
        for j in range(num): 
            #res.append(round(random.uniform(start, end),3)) 
            #res.append(random.randint(start, end))
            res.append(random.choice(list))
  
        return res 
    
    
  
def getNoiseData(dataSet,percent):
    #dataSet = np.delete(dataSet,(0), axis=0)
    size = dataSet.shape
    rows = size[0]
    #print(rows)
    cols = size[1]-1
   
    num = (int)(rows*(percent/100))
    end = np.amax(dataSet,axis=0)
    start = np.amin(dataSet,axis=0)
    #print( start )
    #print( end )
    
    #print(start)
    #print(end)
    i = 0;
    random_val = []
    while i<cols:
        #print(start[i]+" "+end[i])
        random_val.append(RandNoise(start[i],end[i], num))
        #print(start[i])
        #print(end[i])
        i = i+1
    return random_val
#print(random_rows)


def Rand(start, end, num): 
    res = [] 
  
    for j in range(num): 
        res.append(random.randint(start, end)) 
  
    return res
  
def getNoisePlaces(dataSet,percent):
    size = dataSet.shape
    rows = size[0]
    num = (int)(rows*(percent/100))
    start = 0
    end = rows-1
    random_rows=Rand(start, end, num)
    return random_rows

def readData():
    #read both csv files to np array
    print("Reading Data....")

    files = ["abalone.csv"]
    for key in range(0, len(files)):
        orginal_dataset = pd.read_csv("../NumericData/"+files[key])
        size = orginal_dataset.shape
        rows = size[0]
        cols = size[1]-1
        
        #orginal_dataset = orginal_dataset[:int(rows/7)]
        
        #df1 = pd.DataFrame(orginal_dataset)
        #df1.to_csv("../NumericData/clean_"+files[key])
        #print("Saved New File As ../NumericData/clean_"+files[key])
        
        print("Using "+files[key])
    
        percent = [10,20,30,40,50]
        for x in percent:
            print("Adding "+str(x)+"% Noise")
            copy_dataset=orginal_dataset
            random_data = getNoiseData(copy_dataset,x)
        
            size = copy_dataset.shape
            rows = size[0]
            cols = size[1]-1
        
            print(size)
            k = 0
            while k<cols:
                random_places = getNoisePlaces(copy_dataset,x)
                #print(len(random_places))
                j = 0
                while j<len(random_places):
                    a = random_data[k][j]
                    row2change = random_places[j]
                    #print(row2change)
                    if j < 5:
                        print("Changing " +str(copy_dataset.iat[row2change,k])+" To "+str(a))
                    copy_dataset.iloc[row2change,k] = a
                    
                    #copy_dataset.itemset((j,k),a)
                    
                    #print(copy_dataset[j,k])
                    #print(random_data[k][j])
                    j = j+1
                k = k+1
            
            df = pd.DataFrame(copy_dataset)
            df.to_csv("../NumericData/"+str(x)+"_noisy_"+files[key],index=False)
            print("Saved New File As ../NumericData/"+str(x)+"_noisy_"+files[key])
    print("Noise Addition Completed")


readData()
# Out:
# Reading Data....
# Using abalone.csv
# Adding 10% Noise
# (4177, 9)
# Changing F To F
# Changing M To I
# Changing M To F
# Changing I To I
# Changing F To F
# Changing 0.64 To 0.75
# Changing 0.555 To 0.47
# Changing 0.38 To 0.29
# Changing 0.63 To 0.68
# Changing 0.425 To 0.32
# Changing 0.41 To 0.11
# Changing 0.385 To 0.6
# Changing 0.4 To 0.25
# Changing 0.5 To 0.34
# Changing 0.47 To 0.16
# Changing 0.155 To 0.84
# Changing 0.135 To 0.92
# Changing 0.11 To 0.86
# Changing 0.07 To 0.27
# Changing 0.15 To 0.49
# Changing 1.6 To 0.07
# Changing 0.795 To 1.19
# Changing 1.3025 To 1.34
# Changing 1.561 To 2.09
# Changing 1.4880000000000002 To 2.78
# Changing 0.0545 To 1.16
# Changing 0.342 To 1.25
# Changing 0.1925 To 0.16
# Changing 0.368 To 1.17
# Changing 0.5815 To 0.95
# Changing 0.044000000000000004 To 0.72
# Changing 0.12300000000000001 To 0.13
# Changing 0.29 To 0.28
# Changing 0.0405 To 0.47
# Changing 0.201 To 0.69
# Changing 0.205 To 0.49
# Changing 0.005 To 0.77
# Changing 0.26899999999999996 To 0.73
# Changing 0.04 To 0.81
# Changing 0.3885 To 0.9
# Saved New File As ../NumericData/10_noisy_abalone.csv
# Adding 20% Noise
# (4177, 9)
# Changing F To M
# Changing M To F
# Changing I To I
# Changing M To M
# Changing F To I
# Changing 0.4 To 0.47
# Changing 0.59 To 0.17
# Changing 0.61 To 0.73
# Changing 0.66 To 0.43
# Changing 0.56 To 0.45
# Changing 0.48 To 0.64
# Changing 0.405 To 0.4
# Changing 0.525 To 0.12
# Changing 0.35 To 0.12
# Changing 0.455 To 0.41
# Changing 0.16 To 0.44
# Changing 0.06 To 0.15
# Changing 0.135 To 0.12
# Changing 0.15 To 0.82
# Changing 0.165 To 0.63
# Changing 0.892 To 1.2
# Changing 1.235 To 1.38
# Changing 1.2830000000000001 To 1.34
# Changing 0.4025 To 2.5
# Changing 2.71 To 1.9
# Changing 0.258 To 0.17
# Changing 0.5795 To 0.45
# Changing 0.5445 To 0.62
# Changing 0.5005 To 0.83
# Changing 0.4905 To 0.19
# Changing 0.08199999999999999 To 0.57
# Changing 0.1945 To 0.23
# Changing 0.1845 To 0.46
# Changing 0.069 To 0.11
# Changing 0.273 To 0.29
# Changing 0.39399999999999996 To 0.32
# Changing 0.1 To 0.99
# Changing 0.4675 To 0.61
# Changing 0.2505 To 0.19
# Changing 0.387 To 0.28
# Saved New File As ../NumericData/20_noisy_abalone.csv
# Adding 30% Noise
# (4177, 9)
# Changing F To M
# Changing F To M
# Changing I To I
# Changing F To I
# Changing F To F
# Changing 0.44 To 0.76
# Changing 0.34 To 0.59
# Changing 0.59 To 0.22
# Changing 0.38 To 0.16
# Changing 0.77 To 0.48
# Changing 0.305 To 0.5
# Changing 0.225 To 0.5
# Changing 0.355 To 0.55
# Changing 0.49 To 0.22
# Changing 0.2 To 0.07
# Changing 0.12 To 0.26
# Changing 0.18 To 0.05
# Changing 0.79 To 0.01
# Changing 0.165 To 0.66
# Changing 0.17 To 0.86
# Changing 0.5920000000000001 To 2.43
# Changing 0.11 To 0.82
# Changing 1.2645 To 2.61
# Changing 0.59 To 0.05
# Changing 0.6935 To 1.77
# Changing 0.226 To 0.71
# Changing 0.402 To 1.42
# Changing 0.95 To 0.89
# Changing 0.3005 To 0.3
# Changing 0.94 To 1.09
# Changing 0.301 To 0.57
# Changing 0.27899999999999997 To 0.37
# Changing 0.217 To 0.67
# Changing 0.2875 To 0.55
# Changing 0.02 To 0.08
# Changing 0.2035 To 0.43
# Changing 0.17 To 0.49
# Changing 0.2 To 0.17
# Changing 0.425 To 0.55
# Changing 0.135 To 0.61
# Saved New File As ../NumericData/30_noisy_abalone.csv
# Adding 40% Noise
# (4177, 9)
# Changing F To F
# Changing M To I
# Changing M To M
# Changing M To I
# Changing M To M
# Changing 0.38 To 0.17
# Changing 0.72 To 0.79
# Changing 0.35 To 0.26
# Changing 0.46 To 0.81
# Changing 0.62 To 0.2
# Changing 0.285 To 0.24
# Changing 0.45 To 0.3
# Changing 0.51 To 0.43
# Changing 0.27 To 0.44
# Changing 0.47 To 0.27
# Changing 1.06 To 0.42
# Changing 0.79 To 1.05
# Changing 0.18 To 0.83
# Changing 0.32 To 0.29
# Changing 1.08 To 0.33
# Changing 0.41100000000000003 To 1.84
# Changing 2.81 To 0.5
# Changing 1.59 To 1.24
# Changing 0.53 To 0.5
# Changing 1.751 To 0.86
# Changing 1.0 To 0.48
# Changing 0.15 To 0.23
# Changing 0.377 To 0.3
# Changing 0.7365 To 1.02
# Changing 1.1 To 0.87
# Changing 0.59 To 0.37
# Changing 0.19 To 0.36
# Changing 0.62 To 0.33
# Changing 0.71 To 0.49
# Changing 0.0925 To 0.7
# Changing 0.6 To 0.17
# Changing 0.39 To 0.94
# Changing 0.47 To 0.05
# Changing 0.295 To 0.37
# Changing 0.062 To 0.53
# Saved New File As ../NumericData/40_noisy_abalone.csv
# Adding 50% Noise
# (4177, 9)
# Changing I To F
# Changing M To F
# Changing M To I
# Changing M To F
# Changing M To F
# Changing 0.54 To 0.51
# Changing 0.08 To 0.22
# Changing 0.425 To 0.55
# Changing 0.56 To 0.14
# Changing 0.295 To 0.21
# Changing 0.29 To 0.58
# Changing 0.35 To 0.29
# Changing 0.44 To 0.36
# Changing 0.57 To 0.53
# Changing 0.19 To 0.13
# Changing 0.34 To 0.15
# Changing 1.11 To 0.06
# Changing 0.09 To 0.52
# Changing 0.05 To 0.37
# Changing 0.06 To 0.47
# Changing 1.238 To 1.39
# Changing 1.0 To 1.09
# Changing 0.1055 To 1.68
# Changing 1.72 To 0.96
# Changing 0.8240000000000001 To 1.7
# Changing 0.2 To 0.08
# Changing 0.54 To 0.29
# Changing 0.44299999999999995 To 0.18
# Changing 0.7425 To 0.53
# Changing 0.59 To 1.02
# Changing 0.04 To 0.54
# Changing 0.31 To 0.53
# Changing 0.49 To 0.39
# Changing 0.25 To 0.06
# Changing 0.17 To 0.72
# Changing 0.43 To 0.24
# Changing 0.27 To 0.02
# Changing 0.53 To 0.92
# Changing 0.11 To 0.95
# Changing 0.077 To 0.11
# Saved New File As ../NumericData/50_noisy_abalone.csv
# Noise Addition Completed
