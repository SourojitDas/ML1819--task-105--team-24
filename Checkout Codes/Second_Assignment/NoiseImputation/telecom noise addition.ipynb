# %%
import random
import pandas as pd
import numpy as np
import shutil
import os


def getGenderRandom(num): 
    res = []
    list = ['Male','Female']
    for j in range(num): 
        #res.append(round(random.uniform(start, end),3)) 
        #res.append(random.randint(start, end))
        res.append(random.choice(list))
    return res 
def getSeniorRandom(num): 
    res = []
    list = [0,1]
    for j in range(num): 
        #res.append(round(random.uniform(start, end),3)) 
        #res.append(random.randint(start, end))
        res.append(random.choice(list))
    return res 
def getYesNoRandom(num): 
    res = []
    list = ['Yes','No']
    for j in range(num): 
        #res.append(round(random.uniform(start, end),3)) 
        #res.append(random.randint(start, end))
        res.append(random.choice(list))
    return res   
def getYesNoRandom(num): 
    res = []
    list = ['Yes','No','No internet service']
    for j in range(num): 
        #res.append(round(random.uniform(start, end),3)) 
        #res.append(random.randint(start, end))
        res.append(random.choice(list))
    return res  
  
def getNoiseData(dataSet,percent):
    #dataSet = np.delete(dataSet,(0), axis=0)
    size = dataSet.shape
    rows = size[0]
    #print(rows)
    cols = size[1]-1
   
    num = (int)(rows*(percent/100))
    end = np.amax(dataSet,axis=0)
    start = np.amin(dataSet,axis=0)
    #print( start )
    #print( end )
    
    #print(start)
    #print(end)
    i = 0;
    random_val = []
    while i<cols:
        #print(start[i]+" "+end[i])
        random_val.append(RandNoise(start[i],end[i], num))
        #print(start[i])
        #print(end[i])
        i = i+1
    return random_val
#print(random_rows)


def Rand(start, end, num): 
    res = [] 
  
    for j in range(num): 
        res.append(random.randint(start, end)) 
  
    return res
  
def getNoisePlaces(dataSet,percent):
    size = dataSet.shape
    rows = size[0]
    num = (int)(rows*(percent/100))
    start = 0
    end = rows-1
    random_rows=Rand(start, end, num)
    return random_rows

def readData():
    #read both csv files to np array
    print("Reading Data....")

    files = ["telecom.csv"]
    for key in range(0, len(files)):
        orginal_dataset = pd.read_csv("../NumericData/"+files[key])
        size = orginal_dataset.shape
        rows = size[0]
        cols = size[1]
        
        #orginal_dataset = orginal_dataset[:int(rows/7)]
        
        #df1 = pd.DataFrame(orginal_dataset)
        #df1.to_csv("../NumericData/clean_"+files[key])
        #print("Saved New File As ../NumericData/clean_"+files[key])
        
        print("Using "+files[key])
    
        percent = [10,20,30,40,50]
        for x in percent:
            print("Adding "+str(x)+"% Noise")
            copy_dataset=orginal_dataset
            #random_data = getNoiseData(copy_dataset,x)
        
            print(size)
            #k = 0
            #while k<cols:
                #random_places = getNoisePlaces(copy_dataset,x)
                #print(len(random_places))
                #j = 0
                #while j<len(random_places):
                    #a = random_data[k][j]
                    #row2change = random_places[j]
                    #print(row2change)
                    #if j < 5:
                        #print("Changing " +str(copy_dataset.iat[row2change,k])+" To "+str(a))
                    #copy_dataset.iloc[row2change,k] = a
                    
                    #copy_dataset.itemset((j,k),a)
                    
                    #print(copy_dataset[j,k])
                    #print(random_data[k][j])
                    #j = j+1
                #k = k+1
            
            #df = pd.DataFrame(copy_dataset)
            #df.to_csv("../NumericData/"+str(x)+"_noisy_"+files[key],index=False)
            
            for col in copy_dataset:
                print (col)
                if "gender" in col:
                    random_values = getGenderRandom((int)(rows*(x/100)))
                    random_places = getNoisePlaces(copy_dataset,x)
                    j = 0
                    while j<len(random_places):
                        a = random_values[j]
                        row2change = random_places[j]
                        if j < 2:
                            print("Changing " +str(copy_dataset.loc[j,col])+" To "+str(a))
                            
                        copy_dataset.loc[j,col] = a
                        #if j < 2:
                            #print(str(copy_dataset.loc[j,col]))
                        j = j+1
                if "SeniorCitizen" in col:
                    random_values = getSeniorRandom((int)(rows*(x/100)))
                    random_places = getNoisePlaces(copy_dataset,x)
                    j = 0
                    while j<len(random_places):
                        a = random_values[j]
                        row2change = random_places[j]
                        if j < 2:
                            print("Changing " +str(copy_dataset.loc[j,col])+" To "+str(a))
                            
                        copy_dataset.loc[j,col] = a
                        #if j < 2:
                            #print(str(copy_dataset.loc[j,col]))
                        j = j+1
                vallist = ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
                if any(col in s for s in vallist):
                    random_values = getYesNoRandom((int)(rows*(x/100)))
                    random_places = getNoisePlaces(copy_dataset,x)
                    j = 0
                    while j<len(random_places):
                        a = random_values[j]
                        row2change = random_places[j]
                        if j < 2:
                            print("Changing " +str(copy_dataset.loc[j,col])+" To "+str(a))
                            
                        copy_dataset.loc[j,col] = a
                        #if j < 2:
                            #print(str(copy_dataset.loc[j,col]))
                        j = j+1
                vallist = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV','StreamingMovies']
                if any(col in s for s in vallist):
                    random_values = getYesNoInternetRandom((int)(rows*(x/100)))
                    random_places = getNoisePlaces(copy_dataset,x)
                    j = 0
                    while j<len(random_places):
                        a = random_values[j]
                        row2change = random_places[j]
                        if j < 2:
                            print("Changing " +str(copy_dataset.loc[j,col])+" To "+str(a))
                            
                        copy_dataset.loc[j,col] = a
                        #if j < 2:
                            #print(str(copy_dataset.loc[j,col]))
                        j = j+1
                
                    
                    
                            
            
            print("Saved New File As ../NumericData/"+str(x)+"_noisy_"+files[key])
    print("Noise Addition Completed")


readData()
# Out:
# Reading Data....
# Using telecom.csv
# Adding 10% Noise
# (7043, 21)
# customerID
# gender
# Changing Female To Female
# Changing Male To Female
# SeniorCitizen
# Changing 0 To 0
# Changing 0 To 1
# Partner
# Changing Yes To No internet service
# Changing No To No
# Dependents
# Changing No To No internet service
# Changing No To No internet service
# tenure
# PhoneService
# Changing No To Yes
# Changing Yes To Yes
# MultipleLines
# InternetService
# OnlineSecurity
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-97d28a125ede> in <module>
#     201
#     202
# --> 203 readData()
#
# <ipython-input-20-97d28a125ede> in readData()
#     179                 vallist = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV','StreamingMovies']
#     180                 if any(col in s for s in vallist):
# --> 181                     random_values = getYesNoInternetRandom((int)(rows*(x/100)))
#     182                     random_places = getNoisePlaces(copy_dataset,x)
#     183                     j = 0
#
# NameError: name 'getYesNoInternetRandom' is not defined
